# %%
import pandas as pd
cali_data = pd.read_csv("ca_migration3.csv")
cali_year = pd.read_csv("delta_caliyearly.csv")
#DA20191127.txt

# %%
cali_data
# Out:
#              County  netMigration  Year
# 0           Alameda         36453  2014
# 1            Alpine         20938  2013
# 2            Amador         16983  2014
# 3             Butte         15065  2014
# 4         Calaveras         14239  2014
# 5            Colusa         18942  2014
# 6      Contra Costa         32064  2014
# 7         Del Norte         29834  2014
# 8         El Dorado         14850  2014
# 9            Fresno         13271  2014
# 10            Glenn         18934  2014
# 11         Humboldt         10677  2014
# 12         Imperial         12868  2014
# 13             Inyo          7342  2014
# 14             Kern          6883  2014
# 15            Kings          9109  2014
# 16             Lake         19029  2014
# 17           Lassen         16092  2014
# 18      Los Angeles         18183  2014
# 19           Madera          3710  2014
# 20            Marin         45341  2014
# 21         Mariposa          3549  2014
# ...

# %%
del cali_year['Unnamed: 0']

# %%
cali_year.columns = ['County', '2010-2011Delta', '2012-2011Delta', '2013-2012Delta', 
                '2014-2013Delta', '2015-2014Delta', '2016-2015Delta', '2017-2016Delta']
cali_year
# Out:
#              County  2010-2011Delta  2012-2011Delta  2013-2012Delta  \
# 0           Alameda            3331            3439            3656
# 1             Butte            -999            3257            2049
# 2      Contra Costa            2926             969            5407
# 3         El Dorado           -3185            6289           -2158
# 4     Fresno County            -144            -506            1894
# 5          Humboldt            -634             361            -285
# 6          Imperial             699           -3315            5450
# 7              Kern            -384            2655             294
# 8             Kings            3476             110           -2228
# 9              Lake            3302           -5638            5453
# 10      Los Angeles            1563              36            3101
# 11           Madera           -7719             -65             631
# 12            Marin           -4432           17144           11491
# ...

# %%
df_outer = pd.merge(cali_data, cali_year, on='County', how='outer')

df_outer.to_csv('Big_data.csv')

# %%
big_d = pd.read_csv("Big_data.csv")

# %%
cali_1011 = pd.DataFrame()
cali_1011['County'] = big_d['County']
cali_1011['netMigration'] = big_d['2010-2011Delta']
cali_1011['Year'] = big_d['Year']
cali_1112 = pd.DataFrame()
cali_1112['County'] = big_d['County']
cali_1112['netMigration'] = big_d['2012-2011Delta']
cali_1112['Year'] = big_d['Year']
cali_1213 = pd.DataFrame()
cali_1213['County'] = big_d['County']
cali_1213['netMigration'] = big_d['2013-2012Delta']
cali_1213['Year'] = big_d['Year']
cali_1314 = pd.DataFrame()
cali_1314['County'] = big_d['County']
cali_1314['netMigration'] = big_d['2014-2013Delta']
cali_1314['Year'] = big_d['Year']
cali_1415 = pd.DataFrame()
cali_1415['County'] = big_d['County']
cali_1415['netMigration'] = big_d['2015-2014Delta']
cali_1415['Year'] = big_d['Year']
cali_1516 = pd.DataFrame()
cali_1516['County'] = big_d['County']
cali_1516['netMigration'] = big_d['2016-2015Delta']
cali_1516['Year'] = big_d['Year']
cali_1617 = pd.DataFrame()
cali_1617['County'] = big_d['County']
cali_1617['netMigration'] = big_d['2017-2016Delta']
cali_1617['Year'] = big_d['Year']

# %%
cali_1112
# Out:
#              County  netMigration  Year
# 0           Alameda          3439  2014
# 1            Alpine          1873  2013
# 2            Amador          1734  2014
# 3             Butte          3257  2014
# 4         Calaveras           932  2014
# 5            Colusa          2421  2014
# 6      Contra Costa           969  2014
# 7         Del Norte          3221  2014
# 8         El Dorado          6289  2014
# 9            Fresno          -506  2014
# 10            Glenn          2231  2014
# 11         Humboldt           361  2014
# 12         Imperial         -3315  2014
# 13             Inyo           591  2014
# 14             Kern          2655  2014
# 15            Kings           110  2014
# 16             Lake         -5638  2014
# 17           Lassen          1922  2014
# 18      Los Angeles            36  2014
# 19           Madera           -65  2014
# 20            Marin         17144  2014
# 21         Mariposa           521  2014
# ...

# %%
cali_1011.to_csv('cali_1011.csv')
cali_1112.to_csv('cali_1112.csv')
cali_1213.to_csv('cali_1213.csv')
cali_1314.to_csv('cali_1314.csv')
cali_1415.to_csv('cali_1415.csv')
cali_1516.to_csv('cali_1516.csv')
cali_1617.to_csv('cali_1617.csv')

# %%
pd.options.display.max_rows=1000

# %%
bigMayidd
# Out:
#      Year  Period                    Area Adjusted Preliminary  \
# 0    2010  Annual          Alameda County  Not Adj  Not Prelim
# 1    2010  Annual           Alpine County  Not Adj  Not Prelim
# 2    2010  Annual           Amador County  Not Adj  Not Prelim
# 3    2010  Annual            Butte County  Not Adj  Not Prelim
# 4    2010  Annual        Calaveras County  Not Adj  Not Prelim
# 5    2010  Annual           Colusa County  Not Adj  Not Prelim
# 6    2010  Annual     Contra Costa County  Not Adj  Not Prelim
# 7    2010  Annual        Del Norte County  Not Adj  Not Prelim
# 8    2010  Annual        El Dorado County  Not Adj  Not Prelim
# 9    2010  Annual           Fresno County  Not Adj  Not Prelim
# 10   2010  Annual            Glenn County  Not Adj  Not Prelim
# 11   2010  Annual         Humboldt County  Not Adj  Not Prelim
# 12   2010  Annual         Imperial County  Not Adj  Not Prelim
# 13   2010  Annual             Inyo County  Not Adj  Not Prelim
# ...

# %%
bigMayidd = pd.read_csv("DA20191130.txt")
bigMayidd.set_index('Area', inplace=True)
data2010 = bigMayidd[0:58]
data2011 = pd.DataFrame()
data2011 = bigMayidd[58:116]
data2012 = bigMayidd[116:174]
data2013 = bigMayidd[174:232]
data2014 = bigMayidd[232:290]
data2015 = bigMayidd[290:348]
data2016 = bigMayidd[348:406]
data2017 = bigMayidd[406:464]
data2018 = bigMayidd[464:]

data2010['2011'] = data2011['Unemployment Rate']
data2010['2012'] = data2012['Unemployment Rate']
data2010['2013'] = data2013['Unemployment Rate']
data2010['2014'] = data2014['Unemployment Rate']
data2010['2015'] = data2015['Unemployment Rate']
data2010['2016'] = data2016['Unemployment Rate']
data2010['2017'] = data2017['Unemployment Rate']
data2010['2018'] = data2018['Unemployment Rate']
data2010


datamerge = pd.DataFrame()

datamerge['Counties'] = data2010.index
datamerge.set_index('Counties', inplace=True)
datamerge['2010'] = data2010['Unemployment Rate']
datamerge['2011'] = data2010['2011']
datamerge['2012'] = data2010['2012']
datamerge['2013'] = data2010['2013']
datamerge['2014'] = data2010['2014']
datamerge['2015'] = data2010['2015']
datamerge['2016'] = data2010['2016']
datamerge['2017'] = data2010['2017']
datamerge['2018'] = data2010['2018']
datamerge
datamerge.to_csv('bigdata2.csv')

# datamerge['2012'] = data2012['Unemployment Rate']
# datamerge['2013'] = data2013['Unemployment Rate']
# datamerge['2014'] = data2014['Unemployment Rate']
# datamerge['2015'] = data2015['Unemployment Rate']
# datamerge['2016'] = data2016['Unemployment Rate']
# datamerge['2017'] = data2017['Unemployment Rate']
# datamerge['2018'] = data2018['Unemployment Rate']
# Out:
# /Users/azamora2/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/azamora2/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/azamora2/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
bigdata2 = pd.read_csv("bigdata2.csv")
bigdata2['County'] = bigdata2['Counties']
cali_data = pd.read_csv("ca_migration3.csv")
df_outer2 = pd.merge(cali_data, bigdata2, on='County', how='outer')
df_outer2.head()
# Out:
#       County  netMigration  Year   Counties  2010  2011  2012  2013  2014  \
# 0    Alameda         36453  2014    Alameda  10.9  10.1   8.7   7.2   5.8
# 1     Alpine         20938  2013     Alpine  12.9  12.8  11.2   9.7   8.2
# 2     Amador         16983  2014     Amador  14.1  13.6  12.3  10.3   8.3
# 3      Butte         15065  2014      Butte  13.9  13.7  12.2  10.3   8.6
# 4  Calaveras         14239  2014  Calaveras  14.4  14.0  12.4   9.9   8.0
#
#    2015  2016  2017  2018
# 0   4.7   4.3   3.7   3.0
# 1   7.3   6.5   6.2   4.6
# 2   6.6   5.9   5.0   4.0
# 3   7.2   6.6   5.8   4.9
# 4   6.4   5.7   4.7   4.0

# %%
unemp_1011 = pd.DataFrame()
unemp_1011['County'] = df_outer2['County']
unemp_1011['netMigration'] = df_outer2['2010']
unemp_1011['Year'] = df_outer2['Year']
unemp_1012 = pd.DataFrame()
unemp_1012['County'] = df_outer2['County']
unemp_1012['netMigration'] = df_outer2['2011']
unemp_1012['Year'] = df_outer2['Year']
unemp_1013 = pd.DataFrame()
unemp_1013['County'] = df_outer2['County']
unemp_1013['netMigration'] = df_outer2['2012']
unemp_1013['Year'] = df_outer2['Year']
unemp_1014 = pd.DataFrame()
unemp_1014['County'] = df_outer2['County']
unemp_1014['netMigration'] = df_outer2['2013']
unemp_1014['Year'] = df_outer2['Year']
unemp_1015 = pd.DataFrame()
unemp_1015['County'] = df_outer2['County']
unemp_1015['netMigration'] = df_outer2['2014']
unemp_1015['Year'] = df_outer2['Year']
unemp_1016 = pd.DataFrame()
unemp_1016['County'] = df_outer2['County']
unemp_1016['netMigration'] = df_outer2['2015']
unemp_1016['Year'] = df_outer2['Year']
unemp_1017 = pd.DataFrame()
unemp_1017['County'] = df_outer2['County']
unemp_1017['netMigration'] = df_outer2['2016']
unemp_1017['Year'] = df_outer2['Year']
unemp_1018 = pd.DataFrame()
unemp_1018['County'] = df_outer2['County']
unemp_1018['netMigration'] = df_outer2['2017']
unemp_1018['Year'] = df_outer2['Year']
unemp_1019 = pd.DataFrame()
unemp_1019['County'] = df_outer2['County']
unemp_1019['netMigration'] = df_outer2['2018']
unemp_1019['Year'] = df_outer2['Year']

# %%
unemp_1011.to_csv('unemp2010.csv')
unemp_1012.to_csv('unemp2011.csv')
unemp_1013.to_csv('unemp2012.csv')
unemp_1014.to_csv('unemp2013.csv')
unemp_1015.to_csv('unemp2014.csv')
unemp_1016.to_csv('unemp2015.csv')
unemp_1017.to_csv('unemp2016.csv')
unemp_1018.to_csv('unemp2017.csv')
unemp_1019.to_csv('unemp2018.csv')

# %%
import pandas as pd 

zam_1011= pd.read_csv("cali_1011.csv")
zam_1112= pd.read_csv("cali_1112.csv")
zam_1213= pd.read_csv("cali_1213.csv")
zam_1314= pd.read_csv("cali_1314.csv")
zam_1415= pd.read_csv("cali_1415.csv")
zam_1516= pd.read_csv("cali_1516.csv")
zam_1617= pd.read_csv("cali_1617.csv")
zam_1017= pd.read_csv("Big_data.csv")

# %%
zam_1011 = zam_1011.drop(['Unnamed: 0'], axis=1)
zam_1112 = zam_1112.drop(['Unnamed: 0'], axis=1)
zam_1213 = zam_1213.drop(['Unnamed: 0'], axis=1)
zam_1314 = zam_1314.drop(['Unnamed: 0'], axis=1)
zam_1415 = zam_1415.drop(['Unnamed: 0'], axis=1)
zam_1516 = zam_1516.drop(['Unnamed: 0'], axis=1)
zam_1617 = zam_1617.drop(['Unnamed: 0'], axis=1)

# %%
zam_1011['netMigration2'] = zam_1011['netMigration']
zam_1011['netMigration3'] = zam_1011['netMigration']

# %%
zam_1011['netMigration2'] = zam_1011['netMigration'].clip(0, max(zam_1011['netMigration']))
zam_1011['netMigration3'] = zam_1011['netMigration'].clip(min(zam_1011['netMigration']), 0)
zam_1112['netMigration2'] = zam_1112['netMigration'].clip(0, max(zam_1112['netMigration']))
zam_1112['netMigration3'] = zam_1112['netMigration'].clip(min(zam_1112['netMigration']), 0)
zam_1213['netMigration2'] = zam_1213['netMigration'].clip(0, max(zam_1213['netMigration']))
zam_1213['netMigration3'] = zam_1213['netMigration'].clip(min(zam_1213['netMigration']), 0)
zam_1314['netMigration2'] = zam_1314['netMigration'].clip(0, max(zam_1314['netMigration']))
zam_1314['netMigration3'] = zam_1314['netMigration'].clip(min(zam_1314['netMigration']), 0)
zam_1415['netMigration2'] = zam_1415['netMigration'].clip(0, max(zam_1415['netMigration']))
zam_1415['netMigration3'] = zam_1415['netMigration'].clip(min(zam_1415['netMigration']), 0)
zam_1516['netMigration2'] = zam_1516['netMigration'].clip(0, max(zam_1516['netMigration']))
zam_1516['netMigration3'] = zam_1516['netMigration'].clip(min(zam_1516['netMigration']), 0)
zam_1617['netMigration2'] = zam_1617['netMigration'].clip(0, max(zam_1617['netMigration']))
zam_1617['netMigration3'] = zam_1617['netMigration'].clip(min(zam_1617['netMigration']), 0)
zam_1017['netMigration2'] = zam_1017['netMigration'].clip(0, max(zam_1017['netMigration']))
zam_1017['netMigration3'] = zam_1017['netMigration'].clip(0, 0)

# %%
zam_1011['netMigration3'] = zam_1011['netMigration3'].abs()
zam_1112['netMigration3'] = zam_1112['netMigration3'].abs()
zam_1213['netMigration3'] = zam_1213['netMigration3'].abs()
zam_1314['netMigration3'] = zam_1314['netMigration3'].abs()
zam_1415['netMigration3'] = zam_1415['netMigration3'].abs()
zam_1516['netMigration3'] = zam_1516['netMigration3'].abs()
zam_1617['netMigration3'] = zam_1617['netMigration3'].abs()
zam_1017['netMigration3'] = zam_1017['netMigration3'].abs()

# %%
zam_1017
# Out:
#              County  netMigration  Year  2010-2011Delta  2012-2011Delta  \
# 0           Alameda         36453  2014            3331            3439
# 1            Alpine         20938  2013            2044            1873
# 2            Amador         16983  2014            1487            1734
# 3             Butte         15065  2014            -999            3257
# 4         Calaveras         14239  2014            1302             932
# 5            Colusa         18942  2014            1921            2421
# 6      Contra Costa         32064  2014            2926             969
# 7         Del Norte         29834  2014            2984            3221
# 8         El Dorado         14850  2014           -3185            6289
# 9            Fresno         13271  2014            -144            -506
# 10            Glenn         18934  2014            1913            2231
# 11         Humboldt         10677  2014            -634             361
# ...

# %%
zam_1011.to_csv('cali_1011.csv')
zam_1112.to_csv('cali_1112.csv')
zam_1213.to_csv('cali_1213.csv')
zam_1314.to_csv('cali_1314.csv')
zam_1415.to_csv('cali_1415.csv')
zam_1516.to_csv('cali_1516.csv')
zam_1617.to_csv('cali_1617.csv')
zam_1017.to_csv('Big_data.csv')

# %%
un2010= pd.read_csv("unemp2010.csv")
un2011= pd.read_csv("unemp2011.csv")
un2012= pd.read_csv("unemp2012.csv")
un2013= pd.read_csv("unemp2013.csv")
un2014= pd.read_csv("unemp2014.csv")
un2015= pd.read_csv("unemp2015.csv")
un2016= pd.read_csv("unemp2016.csv")
un2017= pd.read_csv("unemp2017.csv")
un2018= pd.read_csv("unemp2018.csv")

# %%
un2010['netMigration2'] = un2010['netMigration']
un2011['netMigration2'] = un2011['netMigration']
un2012['netMigration2'] = un2012['netMigration']
un2013['netMigration2'] = un2013['netMigration']
un2014['netMigration2'] = un2014['netMigration']
un2015['netMigration2'] = un2015['netMigration']
un2016['netMigration2'] = un2016['netMigration']
un2017['netMigration2'] = un2017['netMigration']
un2018['netMigration2'] = un2018['netMigration']

un2010['netMigration3'] = un2010['netMigration'].clip(0, 0)
un2011['netMigration3'] = un2011['netMigration'].clip(0, 0)
un2012['netMigration3'] = un2012['netMigration'].clip(0, 0)
un2013['netMigration3'] = un2013['netMigration'].clip(0, 0)
un2014['netMigration3'] = un2014['netMigration'].clip(0, 0)
un2015['netMigration3'] = un2015['netMigration'].clip(0, 0)
un2016['netMigration3'] = un2016['netMigration'].clip(0, 0)
un2017['netMigration3'] = un2017['netMigration'].clip(0, 0)
un2018['netMigration3'] = un2018['netMigration'].clip(0, 0)

# %%
un2010.to_csv('unemp2010.csv')
un2011.to_csv('unemp2011.csv')
un2012.to_csv('unemp2012.csv')
un2013.to_csv('unemp2013.csv')
un2014.to_csv('unemp2014.csv')
un2015.to_csv('unemp2015.csv')
un2016.to_csv('unemp2016.csv')
un2017.to_csv('unemp2017.csv')
un2018.to_csv('unemp2018.csv')

# %%
import pandas as pd
bigd = pd.read_csv('Big_data1.csv')
bigd2 = pd.read_csv('bigdata2.csv')

# %%
bigd = bigd.drop(['Unnamed: 0'], axis=1)

# %%
result = bigd.transpose()
result2 = bigd2.transpose()

# %%
result2.columns = result2.iloc[0]

# %%
result2 = result2.iloc[1:]

# %%
result2
# Out:
# Counties Alameda Alpine Amador Butte Calaveras Colusa Contra Costa Del Norte  \
# 2010        10.9   12.9   14.1  13.9      14.4   20.8           11      13.2
# 2011        10.1   12.8   13.6  13.7        14   21.2         10.3      13.3
# 2012         8.7   11.2   12.3  12.2      12.4   20.7          8.9      13.5
# 2013         7.2    9.7   10.3  10.3       9.9   18.9          7.5      11.8
# 2014         5.8    8.2    8.3   8.6         8   17.4          6.2      10.1
# 2015         4.7    7.3    6.6   7.2       6.4   15.4            5       8.5
# 2016         4.3    6.5    5.9   6.6       5.7   15.5          4.5       7.5
# 2017         3.7    6.2      5   5.8       4.7   14.2          3.8       6.4
# 2018           3    4.6      4   4.9         4   12.9          3.2       5.5
#
# Counties El Dorado Fresno  ... Sonoma Stanislaus Sutter Tehama Trinity Tulare  \
# 2010          12.2   16.7  ...   10.8       16.9   18.4   15.4      17   17.2
# ...

# %%
result.columns = result.iloc[0]
result = result.iloc[3:10]

# %%
result
# Out:
# County         Alameda Alpine Amador  Butte Calaveras Colusa Contra Costa  \
# 2010-2011Delta    3331   2044   1487   -999      1302   1921         2926
# 2012-2011Delta    3439   1873   1734   3257       932   2421          969
# 2013-2012Delta    3656   2917   1142   2049      1598   1543         5407
# 2014-2013Delta    3076   1583   1932   5141      1723   2334         5201
# 2015-2014Delta    6948  -2234    900  -3036      1183   2021         2458
# 2016-2015Delta    8558   3093   1834   4076      1983   1921         7119
# 2017-2016Delta    7445   2406   1784   4577      1508   2057         7984
#
# County         Del Norte El Dorado Fresno  ... Sonoma Stanislaus Sutter  \
# 2010-2011Delta      2984     -3185   -144  ...   4597      -3733   3561
# 2012-2011Delta      3221      6289   -506  ...   1847       2771   1775
# 2013-2012Delta      2732     -2158   1894  ...   3137       5528   2139
# 2014-2013Delta      3322      8510   1328  ...   6789      -1902   2692
# ...

# %%
result.to_csv('p4deltas.csv')
result2.to_csv('p3deltas.csv')
